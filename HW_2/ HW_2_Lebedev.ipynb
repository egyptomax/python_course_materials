# %%
# %matplotlib inline
import requests
from bs4 import BeautifulSoup
import os
import pandas as pd
import time
import re
import seaborn
from lxml import html
import matplotlib

# %config InlineBackend.figure_format = 'svg'
from pylab import rcParams
rcParams['figure.figsize'] = 8, 5

# %% [markdown]
# Получаем 250 самых топовых фильмов

# %%
url = 'http://www.imdb.com/chart/top'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')

# %% [markdown]
# Парсим страницу с фильмами и получаем грязные данные с
#
#
# 1.   Названием фильма
# 2.   Рейтингом
# 3.   Командой
# 4.   Ссылкой на основную страницу

# %%
movies = soup.select('td.titleColumn')
links = [a.attrs.get('href') for a in soup.select('td.titleColumn a')]
crew = [a.attrs.get('title') for a in soup.select('td.titleColumn a')]
ratings = [b.attrs.get('data-value') for b in soup.select('td.posterColumn span[name=ir]')]

# %%
data_frame = {
    "movies": movies,
    "ratings": ratings,
    "crew": crew,
    "links": links
}

data = pd.DataFrame(data_frame)
data
# Out:
#                                                 movies            ratings  \
# 0    [\n      1.\n      , [Побег из Шоушенка], \n, ...  9.235338166350983
# 1    [\n      2.\n      , [Крёстный отец], \n, [(19...  9.156149805516584
# 2    [\n      3.\n      , [Темный рыцарь], \n, [(20...  8.989783750192025
# 3    [\n      4.\n      , [Крёстный отец 2], \n, [(...  8.984110580366114
# 4    [\n      5.\n      , [12 рaзгневанных мужчин],...  8.951316965515737
# ..                                                 ...                ...
# 245  [\n      246.\n      , [Стальной гигант], \n, ...  8.005612074780945
# 246  [\n      247.\n      , [Аладдин], \n, [(1992)]...  8.004992519306727
# 247  [\n      248.\n      , [Прислуга], \n, [(2011)...  8.004934677240575
# 248  [\n      249.\n      , [Ганди], \n, [(1982)], \n]  8.003994442721847
# 249  [\n      250.\n      , [Du rififi chez les hom...   8.00225436585112
#
#                                                   crew              links
# 0    Frank Darabont (dir.), Tim Robbins, Morgan Fre...  /title/tt0111161/
# 1    Francis Ford Coppola (dir.), Marlon Brando, Al...  /title/tt0068646/
# 2    Christopher Nolan (dir.), Christian Bale, Heat...  /title/tt0468569/
# 3    Francis Ford Coppola (dir.), Al Pacino, Robert...  /title/tt0071562/
# 4        Sidney Lumet (dir.), Henry Fonda, Lee J. Cobb  /title/tt0050083/
# ..                                                 ...                ...
# 245  Brad Bird (dir.), Eli Marienthal, Harry Connic...  /title/tt0129167/
# 246  Ron Clements (dir.), Scott Weinger, Robin Will...  /title/tt0103639/
# 247        Tate Taylor (dir.), Viola Davis, Emma Stone  /title/tt1454029/
# 248  Richard Attenborough (dir.), Ben Kingsley, Joh...  /title/tt0083987/
# 249     Jules Dassin (dir.), Jean Servais, Carl Möhner  /title/tt0048021/
#
# [250 rows x 4 columns]

# %% [markdown]
# Несколько функциий для преобзразования грязных заголовков с названием фильмов

# %%
def process_text_mv(text):
    data = text.get_text().split("\n")
    return data[2].strip()

# %%
def process_text_year(text):
    data = text.get_text().split("\n")
    return data[3].strip()[1:-1]

# %%
data["title"] = data.movies.apply(process_text_mv)
data["year"] = data.movies.apply(process_text_year)

# %%
data.head()
# Out:
#                                               movies            ratings  \
# 0  [\n      1.\n      , [The Shawshank Redemption...  9.239907206438563
# 1  [\n      2.\n      , [The Godfather], \n, [(19...  9.160916749679123
# 2  [\n      3.\n      , [The Dark Knight], \n, [(...  8.992906485653204
# 3  [\n      4.\n      , [The Godfather: Part II],...  8.990104037824768
# 4  [\n      5.\n      , [12 Angry Men], \n, [(195...  8.950443397398235
#
#                                                 crew              links  \
# 0  Frank Darabont (dir.), Tim Robbins, Morgan Fre...  /title/tt0111161/
# 1  Francis Ford Coppola (dir.), Marlon Brando, Al...  /title/tt0068646/
# 2  Christopher Nolan (dir.), Christian Bale, Heat...  /title/tt0468569/
# 3  Francis Ford Coppola (dir.), Al Pacino, Robert...  /title/tt0071562/
# 4      Sidney Lumet (dir.), Henry Fonda, Lee J. Cobb  /title/tt0050083/
#
#                       title  year
# 0  The Shawshank Redemption  1994
# 1             The Godfather  1972
# 2           The Dark Knight  2008
# 3    The Godfather: Part II  1974
# 4              12 Angry Men  1957

# %%
data.crew[1]
# Out:
# 'Francis Ford Coppola (dir.), Marlon Brando, Al Pacino'

# %% [markdown]
# Задача 1.
# Получить список всех участников команд (убрать постфикс `(dir.)` у директоров). Найти количество уникальных имен.
#
# Задача 2.
# Получить список всех директоров. Построить распределение (визуализация обязательна) и найти директора(ов), у которого(ых) больше всего фильмов в топе.
#
# Задача 3. Найти участника(ов) команд, у которого(ых) больше всего фильмов в топе.
#
# Задача 4. Построить распределение топовых фильмов по годам
#
# Задача 5. Построить распределение топовых фильмов рейтингу:
#
#
# *   Округлить до сотых и отрисовать
# *   Округлить до десятых и отрисовать
# *   Округлить до целых и отрисовать
#
# Задача 6. Используйте ссылку `http://www.imdb.com/` и динамически добавляя ссылку на фильм из колонки `links` соберите описание фильмов. Пример поиска необходимого текст представлен ниже. Добавьте эту информацию в исходный датафрейм.

# %%
#Задача 1

crew = []
for value in data["crew"].tolist():
    crew.extend(value.split(","))
    
from collections import Counter

crew1 = [x.replace('(dir.)', '') for x in crew]
num_names = len(set(crew1))
print(num_names)
print(crew1)
# Out:
# 536
# ['Frank Darabont ', ' Tim Robbins', ' Morgan Freeman', 'Francis Ford Coppola ', ' Marlon Brando', ' Al Pacino', 'Christopher Nolan ', ' Christian Bale', ' Heath Ledger', 'Francis Ford Coppola ', ' Al Pacino', ' Robert De Niro', 'Sidney Lumet ', ' Henry Fonda', ' Lee J. Cobb', 'Steven Spielberg ', ' Liam Neeson', ' Ralph Fiennes', 'Peter Jackson ', ' Elijah Wood', ' Viggo Mortensen', 'Quentin Tarantino ', ' John Travolta', ' Uma Thurman', 'Peter Jackson ', ' Elijah Wood', ' Ian McKellen', 'Sergio Leone ', ' Clint Eastwood', ' Eli Wallach', 'Robert Zemeckis ', ' Tom Hanks', ' Robin Wright', 'David Fincher ', ' Brad Pitt', ' Edward Norton', 'Peter Jackson ', ' Elijah Wood', ' Ian McKellen', 'Christopher Nolan ', ' Leonardo DiCaprio', ' Joseph Gordon-Levitt', 'Irvin Kershner ', ' Mark Hamill', ' Harrison Ford', 'Lana Wachowski ', ' Keanu Reeves', ' Laurence Fishburne', 'Martin Scorsese ', ' Robert De Niro', ' Ray Liotta', 'Milos Forman ', ' Jack Nicholson', ' Louise Fletcher', 'David Fincher ', ' Morgan Freeman', ' Brad Pitt', 'Akira Kurosawa ', ' Toshirô Mifune', ' Takashi Shimura', 'Frank Capra ', ' James Stewart', ' Donna Reed', 'Jonathan Demme ', ' Jodie Foster', ' Anthony Hopkins', 'Fernando Meirelles ', ' Alexandre Rodrigues', ' Leandro Firmino', 'Steven Spielberg ', ' Tom Hanks', ' Matt Damon', 'Roberto Benigni ', ' Roberto Benigni', ' Nicoletta Braschi', 'Christopher Nolan ', ' Matthew McConaughey', ' Anne Hathaway', 'Frank Darabont ', ' Tom Hanks', ' Michael Clarke Duncan', 'George Lucas ', ' Mark Hamill', ' Harrison Ford', 'James Cameron ', ' Arnold Schwarzenegger', ' Linda Hamilton', 'Robert Zemeckis ', ' Michael J. Fox', ' Christopher Lloyd', 'Hayao Miyazaki ', ' Daveigh Chase', ' Suzanne Pleshette', 'Alfred Hitchcock ', ' Anthony Perkins', ' Janet Leigh', 'Roman Polanski ', ' Adrien Brody', ' Thomas Kretschmann', 'Bong Joon Ho ', ' Song Kang-ho', ' Lee Sun-kyun', 'Luc Besson ', ' Jean Reno', ' Gary Oldman', 'Roger Allers ', ' Matthew Broderick', ' Jeremy Irons', 'Ridley Scott ', ' Russell Crowe', ' Joaquin Phoenix', 'Tony Kaye ', ' Edward Norton', ' Edward Furlong', 'Martin Scorsese ', ' Leonardo DiCaprio', ' Matt Damon', 'Bryan Singer ', ' Kevin Spacey', ' Gabriel Byrne', 'Christopher Nolan ', ' Christian Bale', ' Hugh Jackman', 'Damien Chazelle ', ' Miles Teller', ' J.K. Simmons', 'Michael Curtiz ', ' Humphrey Bogart', ' Ingrid Bergman', 'Masaki Kobayashi ', ' Tatsuya Nakadai', ' Akira Ishihama', 'Isao Takahata ', ' Tsutomu Tatsumi', ' Ayano Shiraishi', 'Olivier Nakache ', ' François Cluzet', ' Omar Sy', 'Charles Chaplin ', ' Charles Chaplin', ' Paulette Goddard', 'Sergio Leone ', ' Henry Fonda', ' Charles Bronson', 'Alfred Hitchcock ', ' James Stewart', ' Grace Kelly', 'Giuseppe Tornatore ', ' Philippe Noiret', ' Enzo Cannavale', 'Ridley Scott ', ' Sigourney Weaver', ' Tom Skerritt', 'Charles Chaplin ', ' Charles Chaplin', ' Virginia Cherrill', 'Francis Ford Coppola ', ' Martin Sheen', ' Marlon Brando', 'Christopher Nolan ', ' Guy Pearce', ' Carrie-Anne Moss', 'Steven Spielberg ', ' Harrison Ford', ' Karen Allen', 'Quentin Tarantino ', ' Jamie Foxx', ' Christoph Waltz', 'Andrew Stanton ', ' Ben Burtt', ' Elissa Knight', 'Florian Henckel von Donnersmarck ', ' Ulrich Mühe', ' Martina Gedeck', 'Billy Wilder ', ' William Holden', ' Gloria Swanson', 'Stanley Kubrick ', ' Kirk Douglas', ' Ralph Meeker', 'Stanley Kubrick ', ' Jack Nicholson', ' Shelley Duvall', 'Charles Chaplin ', ' Charles Chaplin', ' Paulette Goddard', 'Anthony Russo ', ' Robert Downey Jr.', ' Chris Hemsworth', 'Billy Wilder ', ' Tyrone Power', ' Marlene Dietrich', 'James Cameron ', ' Sigourney Weaver', ' Michael Biehn', 'Bob Persichetti ', ' Shameik Moore', ' Jake Johnson', 'Sam Mendes ', ' Kevin Spacey', ' Annette Bening', 'Stanley Kubrick ', ' Peter Sellers', ' George C. Scott', 'Christopher Nolan ', ' Christian Bale', ' Tom Hardy', 'Park Chan-wook ', ' Choi Min-sik', ' Yoo Ji-tae', 'Milos Forman ', ' F. Murray Abraham', ' Tom Hulce', 'Quentin Tarant ...

# %%
#Задача 2
directors = []

item = "(dir.)"
for person in crew:
    if item not in person:
        continue
    if item in person:
        directors.append(person)
directors = [x.replace('(dir.)', '') for x in directors]
print(directors)
# Out:
ira Kurosawa ', 'Guillermo del Toro ', 'Clint Eastwood ', 'Paul Thomas Anderson ', 'Peter Weir ', 'M. Night Shyamalan ', 'Ron Howard ', 'Martin Scorsese ', 'Akira Kurosawa ', 'John Huston ', 'Terry Gilliam ', 'Steven Spielberg ', 'Jon Watts ', 'John Sturges ', 'Akira Kurosawa ', 'Ethan Coen ', 'Quentin Tarantino ', 'John Carpenter ', 'Andrew Stanton ', 'David Lynch ', 'Roman Polanski ', 'Martin Scorsese ', 'James McTeigue ', 'Victor Fleming ', 'Pete Docter ', 'Guy Ritchie ', 'Alfred Hitchcock ', 'Juan José Campanella ', 'Hayao Miyazaki ', 'David Lean ', 'Martin McDonagh ', 'Danny Boyle ', "Gavin O'Connor ", 'Denis Villeneuve ', 'Joel Coen ', 'Clint Eastwood ', 'Hayao Miyazaki ', 'Steven Spielberg ', 'Clint Eastwood ', 'Majid Majidi ', 'Ridley Scott ', 'Charles Chaplin ', 'Elia Kazan ', 'Richard Linklater ', 'Steve McQueen ', 'David Yates ', 'William Wyler ', 'David Fincher ', 'Ingmar Bergman ', 'Carol Reed ', 'Sergio Pablos ', 'Clyde Bruckman ', 'Wes Anderson ', 'Jim Sheridan ', 'Michael Cimino ', 'Stanley Kubrick ', 'Henri-Georges Clouzot ', 'Mel Gibson ', 'Buster Keaton ', 'Frank Capra ', 'Bong Joon Ho ', 'Damián Szifron ', 'Ingmar Bergman ', 'George Miller ', 'Lenny Abrahamson ', 'Adam Elliot ', 'Dean DeBlois ', 'Pete Docter ', 'Joel Coen ', 'Steven Spielberg ', 'Peter Weir ', 'Carl Theodor Dreyer ', 'Yasujirô Ozu ', 'Terry George ', 'James Mangold ', 'John G. Avildsen ', ' ...

# %%
import matplotlib.pyplot as plt

plt.hist(directors, bins = 5)
plt.title('Directors in the top')
plt.xlabel('Directors')
plt.ylabel('Number of films')
plt.show()

# %%
 film_url = 'http://www.imdb.com/title/tt0068646/'
 html_text = requests.get(film_url).text

# %%
soup = BeautifulSoup(html_text, 'lxml')
soup.find_all(attrs={"name": "description"})[0].get("content")
# Out:
# 'The Godfather: Directed by Francis Ford Coppola. With Marlon Brando, Al Pacino, James Caan, Richard S. Castellano. The aging patriarch of an organized crime dynasty in postwar New York City transfers control of his clandestine empire to his reluctant youngest son.'

# %% [markdown]
# Задача 7. С помощью регулярных выражений найдите в текстах описания фильмов имена актеров, если это возможно (то есть - они там упоминаются). Добавьте эту информацию в датафрейм и посчитайте, для скольких фильмов получилось это сдлеать. Подсказка: перечисление актеров иногда начинается с with.
#
#
# Задача 8. Распарсите исходную страницу с топ-250 фильмов и получите для каждого фильмов количество оценок. Пример текста в исходной странице:`9.2 based on 2,554,919 user ratings`. Из этого текста нужно достать = `2,554,919`. Подсказка: используя метод `find_all` с аргументом `attrs` в который нужно передать `{'class': 'ratingColumn imdbRating'}` от страници `http://www.imdb.com/chart/top`. Найдите 10 фильмов (вывести их название и кол-во оценок) у которых, самое большое количество оценок.
#
#
# Задача 9. Постройте топ 10 слов, которые встречаются
#
# 1.   в названии фильмов
# 2.   в описании фильмов
# 3.   в названии и в описании фильмов
#
#
# Задача 10*. Спарсить теги фильмов со страницы каждого фильма, так например для `The Godfather` ожидается получить список из `Crime, Drama`. (Можно увидеть эти теги по картинкой к фильму)
